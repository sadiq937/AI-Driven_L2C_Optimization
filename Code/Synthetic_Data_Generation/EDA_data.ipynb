# %%
import os
import pandas as pd 
import numpy as np 
import matplotlib

# %%
pwd
# Out:
# 'c:\\DataScience\\CPT\\capstone_project\\AI-Driven_L2C_Optimization\\Code\\Synthetic_Data_Generation'

# %%
new_working_directory = "c:\\DataScience\\CPT\\capstone_project\\AI-Driven_L2C_Optimization"
os.chdir(new_working_directory)  # Change the current working directory
print(f"Current working directory changed to: {os.getcwd()}")
# Out:
# Current working directory changed to: c:\DataScience\CPT\capstone_project\AI-Driven_L2C_Optimization

# %%
cyber_df = pd.read_csv("data/synthetic_cybersecurity_L2C_data.csv")
cyber_df.head()
# Out:
#      Lead ID Client ID   Client/Organization Name              Contact Info  \
# 0  LID-15950    C96138    Howard, Payne and Moore  laurierivera@example.net
# 1  LID-32339    C41383     Evans, Woods and Small  jasonanthony@example.net
# 2  LID-22827    C60962                 Steele LLC       lucas78@example.net
# 3  LID-39203    C71377  Singh, Campbell and Lloyd  josephmorris@example.com
# 4  LID-36999    C43964            Richards-Sutton      ojohnson@example.net
#
#         Industry       Security Needs       Lead Source  \
# 0  Manufacturing  Firewall Management        Cold Email
# 1     Healthcare       Cloud Security          Referral
# 2  Manufacturing       Cloud Security        Cold Email
# 3     Technology       Cloud Security          Referral
# 4  Manufacturing       SOC Monitoring  Digital Campaign
#
#          Chatbot Interaction Data           Inquiry Type  \
# 0                  Requested demo  Ransomware Protection
# ...

# %%
cyber_df
# Out:
#          Lead ID Client ID   Client/Organization Name  \
# 0      LID-15950    C96138    Howard, Payne and Moore
# 1      LID-32339    C41383     Evans, Woods and Small
# 2      LID-22827    C60962                 Steele LLC
# 3      LID-39203    C71377  Singh, Campbell and Lloyd
# 4      LID-36999    C43964            Richards-Sutton
# ...          ...       ...                        ...
# 19995  LID-29698    C20864             Brown and Sons
# 19996  LID-73041    C45107  Lloyd, Harvey and Watkins
# 19997  LID-51750    C38630             Miller-Wallace
# 19998  LID-42857    C49823            Wilcox and Sons
# 19999  LID-28555    C64974                Pugh-Fisher
#
#                     Contact Info       Industry       Security Needs  \
# 0       laurierivera@example.net  Manufacturing  Firewall Management
# 1       jasonanthony@example.net     Healthcare       Cloud Security
# 2            lucas78@example.net  Manufacturing       Cloud Security
# ...
